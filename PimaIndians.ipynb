# %%
#importing libs
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %%
#Creating the dataframe
df = pd.read_csv("C:/Users/facla/Documents/CursoPython/Cap11/pima-data.csv")

# %%
df.shape
# Out:
# (768, 10)

# %%
df.head(5)
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age    skin  diabetes
# 0   50  1.3780      True
# 1   31  1.1426     False
# 2   32  0.0000      True
# 3   21  0.9062     False
# 4   33  1.3790      True

# %%
#Checking for null values
df.isnull().values.any()
# Out:
# False

# %%
#Adicionar linha vazia para teste
#df = df.append(pd.Series(), ignore_index=True)

# %%
df.isnull()
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin    bmi  \
# 0       False         False         False      False    False  False
# 1       False         False         False      False    False  False
# 2       False         False         False      False    False  False
# 3       False         False         False      False    False  False
# 4       False         False         False      False    False  False
# ..        ...           ...           ...        ...      ...    ...
# 763     False         False         False      False    False  False
# 764     False         False         False      False    False  False
# 765     False         False         False      False    False  False
# 766     False         False         False      False    False  False
# 767     False         False         False      False    False  False
#
#      diab_pred    age   skin  diabetes
# 0        False  False  False     False
# 1        False  False  False     False
# 2        False  False  False     False
# 3        False  False  False     False
# 4        False  False  False     False
# ..         ...    ...    ...       ...
# 763      False  False  False     False
# 764      False  False  False     False
# 765      False  False  False     False
# 766      False  False  False     False
# 767      False  False  False     False
#
# [768 rows x 10 columns]

# %%
#Remoce linha vazia
#if df.isnull().values.any():
 #   df = df.dropna()

# %%
df.isnull()
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin    bmi  \
# 0       False         False         False      False    False  False
# 1       False         False         False      False    False  False
# 2       False         False         False      False    False  False
# 3       False         False         False      False    False  False
# 4       False         False         False      False    False  False
# ..        ...           ...           ...        ...      ...    ...
# 763     False         False         False      False    False  False
# 764     False         False         False      False    False  False
# 765     False         False         False      False    False  False
# 766     False         False         False      False    False  False
# 767     False         False         False      False    False  False
#
#      diab_pred    age   skin  diabetes
# 0        False  False  False     False
# 1        False  False  False     False
# 2        False  False  False     False
# 3        False  False  False     False
# 4        False  False  False     False
# ..         ...    ...    ...       ...
# 763      False  False  False     False
# 764      False  False  False     False
# 765      False  False  False     False
# 766      False  False  False     False
# 767      False  False  False     False
#
# [768 rows x 10 columns]

# %%
pd.crosstab(index=df['diabetes'], columns='count')
# Out:
# col_0     count
# diabetes
# False       500
# True        268

# %%
import sklearn as sk
from sklearn.model_selection import train_test_split
X = df.values
Y = df["diabetes"].values

# %%
df_train, df_test, y_train, y_teste = train_test_split(df, Y, test_size=0.25, random_state = 42, shuffle = True)

# %%
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 357        13           129             0         30        0  39.9
# 73          4           129            86         20      270  35.1
# 352         3            61            82         28        0  34.4
# 497         2            81            72         15       76  30.1
# 145         0           102            75         23        0   0.0
# ..        ...           ...           ...        ...      ...   ...
# 71          5           139            64         35      140  28.6
# 106         1            96           122          0        0  22.4
# 270        10           101            86         37        0  45.6
# 435         0           141             0          0        0  42.4
# 102         0           125            96          0        0  22.5
#
#      diab_pred  age    skin  diabetes
# 357      0.569   44  1.1820      True
# 73       0.231   23  0.7880     False
# 352      0.243   46  1.1032     False
# 497      0.547   25  0.5910     False
# 145      0.572   21  0.9062     False
# ..         ...  ...     ...       ...
# 71       0.411   26  1.3790     False
# 106      0.207   27  0.0000     False
# 270      1.136   38  1.4578      True
# 435      0.205   29  0.0000      True
# 102      0.262   21  0.0000     False
#
# [576 rows x 10 columns]

# %%
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 668         6            98            58         33      190  34.0
# 324         2           112            75         32        0  35.7
# 624         2           108            64          0        0  30.8
# 690         8           107            80          0        0  24.6
# 473         7           136            90          0        0  29.9
# ..        ...           ...           ...        ...      ...   ...
# 554         1            84            64         23      115  36.9
# 319         6           194            78          0        0  23.5
# 594         6           123            72         45      230  33.6
# 6           3            78            50         32       88  31.0
# 615         3           106            72          0        0  25.8
#
#      diab_pred  age    skin  diabetes
# 668      0.430   43  1.3002     False
# 324      0.148   21  1.2608     False
# 624      0.158   21  0.0000     False
# 690      0.856   34  0.0000     False
# 473      0.210   50  0.0000     False
# ..         ...  ...     ...       ...
# 554      0.471   28  0.9062     False
# 319      0.129   59  0.0000      True
# 594      0.733   34  1.7730     False
# 6        0.248   26  1.2608      True
# 615      0.207   27  0.0000     False
#
# [192 rows x 10 columns]

# %%
df_test.drop('diabetes', inplace=True, axis=1)
df_train.drop('diabetes', inplace=True, axis=1)

# %%
features = ["num_preg",	"glucose_conc",	"diastolic_bp",	"thickness", "insulin",	"bmi", "diab_pred", "age", "skin"]
X = pd.get_dummies(df_train[features])
X_test = pd.get_dummies(df_test[features])

# %%
#Primeiro Modelo (RandomForest)
model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model.fit(X, y_train)
predictions = model.predict(X_test)

# %%
output = pd.DataFrame({'PersonId': df_test.index, 'diabetes': predictions})
output.to_csv('submission.csv', index=False)

# %%
from sklearn import metrics
print("{0:.4f}".format(metrics.accuracy_score(y_teste, predictions)))
# Out:
# 0.7656

# %%
#Segundo modelo (GaussianNB() / naive Bayes)
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
y_pred_gnb = gnb.fit(df_train, y_train).predict(df_test)
print("{0:.4f}".format(metrics.accuracy_score(y_teste, y_pred_gnb)))
# Out:
# 0.7240

# %%
# Out:
# GaussianNB()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21616/2472364965.py in <module>
#       1 gnb.predict(df_test)
#       2 #y_pred_gnb
# ----> 3 print("{0:.4f}".format(metrics.accuracy_score(y_teste, y_pred_gnb)))
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     203
#     204     # Compute accuracy for each possible representation
# --> 205     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     206     check_consistent_length(y_true, y_pred, sample_weight)
#     207     if y_type.startswith("multilabel"):
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     326     """
#     327
# --> 328     lengths = [_num_samples(X) for X in arrays if X is not None]
#     329     uniques = np.unique(lengths)
#     330     if len(uniques) > 1:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in <listcomp>(.0)
#     326     """
#     327
# --> 328     lengths = [_num_samples(X) for X in arrays if X is not None]
#     329     uniques = np.unique(lengths)
#     330     if len(uniques) > 1:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _num_samples(x)
#     256     if hasattr(x, "fit") and callable(x.fit):
#     257         # Don't get num_samples from an ensembles length!
# --> 258         raise TypeError(message)
#     259
#     260     if not hasattr(x, "__len__") and not hasattr(x, "shape"):
#
# TypeError: Expected sequence or array-like, got <class 'sklearn.naive_bayes.GaussianNB'>
